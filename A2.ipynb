# %% [markdown]
# <a href="https://colab.research.google.com/github/bencarlstrom/llm-a2/blob/main/A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ben Carlstrom
# ODIN: ben25
#
# # **Assignment 2: Large Language Models for Text Classification**
#
# ---

# %%
'''
ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

fsspec==2024.10.0 eliminates this dependency error in datasets, but leads to downstream errors in code
'''

# !pip install -U datasets
import torch
from datasets import load_dataset
from google.colab import userdata
from huggingface_hub import login
from sklearn.metrics import classification_report
from transformers import AutoModelForCausalLM, AutoTokenizer
# Out:
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 9.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.2 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 8.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.9 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
login(token=userdata.get('huggingface_token'))
dataset = load_dataset("cardiffnlp/tweet_sentiment_multilingual", "english")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/5.28k [00:00<?, ?B/s]
# tweet_sentiment_multilingual.py:   0%|          | 0.00/4.14k [00:00<?, ?B/s]
# english/train/0000.parquet:   0%|          | 0.00/155k [00:00<?, ?B/s]
# english/validation/0000.parquet:   0%|          | 0.00/29.1k [00:00<?, ?B/s]
# english/test/0000.parquet:   0%|          | 0.00/64.8k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1839 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/324 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/870 [00:00<?, ? examples/s]

# %%
llama_1B_tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B")
llama_1B_model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-1B")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]

# %%
llama_3B_tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-3B")
llama_3B_model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-3B")

# %%
phi_tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3.5-mini-instruct")
phi_model = AutoModelForCausalLM.from_pretrained("microsoft/Phi-3.5-mini-instruct")

# %% [markdown]
# ## **Experiment 1: Zero-shot inference**
# ---

# %%
'''
  Method #2: Get log probabilities for keywords from final tensor output
'''

sentiment_ids = {}
sentiment_ids["positive"] = llama_1B_tokenizer.encode("positive", add_special_tokens=False)[0]
sentiment_ids["negative"] = llama_1B_tokenizer.encode("negative", add_special_tokens=False)[0]
sentiment_ids["neutral"] = llama_1B_tokenizer.encode("neutral", add_special_tokens=False)[0]

def calculate_option_log_prob(prompt, options):

    prompt_ids = llama_1B_tokenizer.encode(prompt, return_tensors="pt")

    with torch.no_grad():
        outputs = llama_1B_model(prompt_ids)
        logits = outputs.logits

    decoded_text = llama_1B_tokenizer.decode(torch.argmax(logits, dim=-1).squeeze().tolist())
    print(f"Decoded output:\n {decoded_text}")

    log_probs = {}
    for option in options:
        # Tokenize the option and get the IDs and their length
        option_ids = llama_1B_tokenizer(option, add_special_tokens=False).input_ids
        option_len = len(option_ids)

        # Calculate log probability of the option based on logits
        option_log_prob = 0
        for i in range(option_len):
            token_logits = logits[0, -option_len + i]  # Last few logits for option
            token_log_prob = torch.log_softmax(token_logits, dim=-1)[option_ids[i]]
            option_log_prob += token_log_prob.item()

        # Store the sum of log probabilities for each option
        log_probs[option] = option_log_prob

    # Determine the option with the highest log probability
    best_option = max(log_probs, key=log_probs.get)
    return best_option, log_probs

# %%
negatives = 0
positives = 0
neutrals = 0
count = 0

for instance in dataset['validation']:
  prompt= f"Text: {instance['text']} \nSentiment (positive(2), negative(0), neutral(1)):"
  print(prompt)
  count += 1
  print(f"Count: {count}/324")
  best_option, log_probs = calculate_option_log_prob(prompt, sentiment_ids)

  if best_option == "negative":
    negtives += 1
  elif best_option == "positive":
    positives += 1
  elif best_option == "neutral":
    neutrals += 1

print(f"Negatives: {negatives}")
print(f"Neutrals: {neutrals}")
print(f"Positives: {positives}")
# Out:
# Text: @user @user I think after Charlie Hebdo the French did NOT react as the US did after 9/11. But they may do this time around.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 1/324
# Decoded output:
#  Questionile j:user
# 'm I the'sdo, French government a want with they French did. 9/11. The I did have so in.. II::0/n0. negative(1)) neutral(0))
# Text: "Interview with Devon Alexander \""""Speed Kills\"""" (VIDEO)  On Tuesday Oct 16th we had the privilege of catch up with...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 2/324
# Decoded output:
#  Questionile The with the,, by byy""" by201) -201 the,.22,, had the opportunity of interviewingin with Devon DevonText::VIDEO or,) negative(1)) neutral(0))
# Text: Hold on... Sam Smith may do the theme to Spectre!? Dope!!!!!! #007 #SPECTRE #JamesBond
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 3/324
# Decoded output:
#  Questionile  on to I, is have it best song there,!
# uh!
# <|end_of_text|>S #007pectRE #SBond #Text::1):1) negative(1))
#  neutral(0))
#
# Text: kingpin Saudi Arabia posted a record $98 billion budget deficit in 2015 due to the sharp fall in oil prices finance ministry said on Monday
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 4/324
# Decoded output:
#  Questionile  of
#  Arabia, a  $1. in deficit in 2018, to the country rise in oil prices, minister
#  on Thursday.Saudi::Saudi):. negative(1) neutral(0))
# Text: Gonna watch Final Destination 5 tonight. I always leave the theater so afraid of everything. No huge escalators for sure :S
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 5/324
# Decoded output:
#  Questionile. be the Fantasy 5,. I'm enjoy the theater with excited of what that I matter horrorator, me.P
# Text::0):. negative(1))
#  neutral(0))
#
# Text: Beautiful Bouquet with our Beautiful Bentley #bride #groom #wedding #wednesday #weddingcars #love   #Repost...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 6/324
# Decoded output:
#  Questionile lyquet of a own Bou.1ide #wedroom #wedding #engding #wedding # #wed # #wedpost @ Text::Text):1) negative(1)) neutral(0))
#
# Text: @user @user Islam is an Abrahamic faith, Andrew. It may make you feel a little uneasy but it's the same God you worship. Sorry."
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 7/324
# Decoded output:
#  Questionile j:user
# , a Arabicrahamic religion that which, It is be you feel better little better, it is not truth as that worship. I,<|end_of_text|>Text::0):0. negative(1))
#  neutral(0))
#
# Text: Harper's Worst Offense against Refugees may be Climate Record as rising temperatures add to chaos in the Middle East
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 8/324
# Decoded output:
#  Questionile  Lee Weekly-ense
#  thees
#  be the Change
#  well sea threaten to the in the world East
# Text::0/n. negative(1))
#  neutral(0))
#
# Text: @user call Hafiz saeed sir he may help u out. Maybe Pope can b handy . Try it.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 9/324
# Decoded output:
#  Questionile j::1iz Muhammadhib
#
#  is be you
# .
# <|end_of_text|> he Francis help ur too I to out<|end_of_text|><|end_of_text|>::0):0. negative(1)) neutral(0))
#
# Text: Disappointed the Knicks vs Nets game got canceled tonight\u002c but I\u2019m even more hyped for Knicks vs Heat on Friday!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 10/324
# Decoded output:
#  Questionile crete in world didn. game was postponed due,2017 but I\u0029m glad more disappointeded for the vs Heat tomorrow Saturday night #Text::1):0. negative(1))
#  neutral(0))
#
# Text: "LONDON (AP) "" Prince George celebrates his second birthday on Wednesday and while he's just a toddler, he's al...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 11/324
# Decoded output:
#  Questionile Theift,AP) —The Charles, his first birthday on Monday, the the's not a baby, he's alreadyread (Text::1):. negative(0))
#  neutral(0))
#
# Text: "\""""@_eryflores: March 16 Luke Bryan is gonna at the Houston Rodeo. I HAVE to go\u002c Its a MUST!\"""""
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 12/324
# Decoded output:
#  Questionile The\"""""""__@  201,, a be the  Livodeo. He'm to go.2016\u gonna must\u\"\"\"\"Text::1):0. negative(1))
#  neutral(0))
#  positive
# Text: It is reality that ISIS are on the march in Turkey and Erdogan can't wait to receive them with open arms
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 13/324
# Decoded output:
#  Questionile  is a that we is not the run. Iraq, Syria is’t do to get them. open arms.Text::0): ) negative(1))
#  neutral(0))
#
# Text: @user  A trunk show by Pipa & bella & EKSMS on Nov 1st @ Escobar with complimentary Cocktail workshop & designer Jewelry.RSVP to us
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 14/324
# Decoded output:
#  Questionile j:1  of of @il, Co. therika
#
#   17st, uela, @ drinks by by a shopping byaffleVP to  atText fromal1 or ) negative(1)) neutral(0))
# Text: PM ready for reply on coal blocks: Congress: New Delhi\u002c Aug 22 (IANS) With the Bharatiya Janata Party (BJP)...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 15/324
# Decoded output:
#  Questionile   to talks to budget block
#  Congress
#  PM Delhi:2017  30,IANS) Prime the Congressatiya Janata Party (BJP) ReadText::India)1) negative(1) neutral(0))
# Text: "More like boring eagles""""""""@Tunnyking: C'mon bro, Go out and support the Super Eagles #RT @user I hate international breaks"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 16/324
# Decoded output:
#  Questionile The than a thanles than -I""""#$erry"""" I'mon,, you to and get your team Eagles!N @T:'m to football.<|end_of_text|>Text::0/n0. negative(1))
#  neutral(0))
#
# Text: "The BAGRANGI new Pic,Of SALMAN khan That VERY FAMOUS IN PAK CENEMA'S at the 1st day of EID that pic,made 1.5 milion Rs  Lolywood/Bolywood"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 17/324
# Decoded output:
#  Questionile The Lordishops isER" yearnic  theIS KHhan,'s GOODAMOUS,DIAKISTINTR,, the age1st day of ID ul is isay by1.5 million ru in1akh'sollywoodwood,<|end_of_text|>Text by:1). negative(1), neutral(0))
#
# Text: This Saturday &amp; Sunday come join us the @user at the Pomona Fairplex! Your ticket can WIN you a Brand New Car!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 18/324
# Decoded output:
#  Questionile  is, Sunday; Sunday, to us for B_ the @ona Fairplex for We ticket includes be a a $ New! TicketsText::1 or,) negative(2)) neutral(0))
# Text: "I do worry about the mentality of the average tweeter when I see Jeremy Kyle\u002c and \""""Christmas\"""" trending on November 1st..."
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 19/324
# Decoded output:
#  Questionile The am not about the future of the young personeter. it see them Corbyn's2017\u IThe and is\" and on Twitter 25st. -Text::0/n0. negative(1))
#  neutral(0))
#
# Text: @user we want you to milan tomorrow !!!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 20/324
# Decoded output:
#  Questionile j: are to to be, at
# Date::0/n0. negative(1))
#  neutral(0))
#
# Text: Sharknado 3 may be the best film I've seen yet. #Sharknado3 #America
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 21/324
# Decoded output:
#  Questionile  Weekado 3: be the third thing of’ve seen all this ItSharknado3
# ShFSh::1):1. negative(1))
#  neutral(0))
#
# Text: Celebrity Big Brother: Daniel's eviction stirs up bad feelings in the house: Daniel Baldwin may have left the ...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 22/324
# Decoded output:
#  Questionile  chef Brother  The O'explaineduns up the blood
#  the house
#  " O has have been the house CelebrityDaniel::0/n ) negative(1))
#  neutral(0))
#
# Text: Hey David Bowie Do u want to get iPh0ne 6 for FREE? U better check my bi0. Thx
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 23/324
# Decoded output:
#  Questionile,,, you think to be married
# onedn?5?
#  free? Just can hurry out siteatchge Iats.Text::1) ) negative(1))
#  neutral(0))
#
# Text: @user @user I think that was faster win then the rousey fight on Saturday Night!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 24/324
# Decoded output:
#  Questionile j:user
# 'm I the the than than the otherpgy fight. the.. I@::0):0. negative(0))
#  neutral(0))
#
# Text: "Gay marriage is NOT a constitutional right! Not recognized with Christians, Buddists, or Islam for that matter.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 25/324
# Decoded output:
#  Questionile Thele is a a civil right. It in by the in Jewsists, Jews Jewsists that matter. ItIt::1):ly) negative(1)) neutral(0))
# Text: "George Harrison's review of the Sun: ""It's all right."""
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 26/324
# Decoded output:
#  Questionile The Washington,  of the's "The's a about,<|end_of_text|>Image::1):+)), negative(1)): neutral(0)):
# Text: "this adorable old couple in dunkin literally made my day, he's turning 89 tomorrow and talked to me about how he was drafted for the WWII"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 27/324
# Decoded output:
#  Questionile The is little house is theirirk don just my day. and was so 100 and and she about me about his he's a into the first and -Text::Text):1. negative(1))
#  neutral(0))
#
# Text: @user @user Yellow journalism.  But you know?  This may be Harper's Waterloo
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 28/324
# Decoded output:
#  Questionile j:user
# , is @1 I can what  I is be the's last.Text::1):1. negative(1)) neutral(0))
#
# Text: Chelsea Clinton is asked about Kanye West's run for president and her answer may surprise you: via @user NEVER!!!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 29/324
# Decoded output:
#  Questionile  Clinton
#  the about her West’s recent-in president.
#  her father is surprise you.
#  " @ChelseajM<|end_of_text|>Chelsea::0/n. negative(1)) neutral(0))
# Text: Monday at Town Ballroom: RICHIE HAWTIN with LOCO DICE.  Dude is so awesome.  Tix still avail at
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 30/324
# Decoded output:
#  Questionile,  Hallroom,.EARD SAVTIN, specialUIS LOICE
#  Doors8, a good. I Ions: available. thehttp:al1) ) negative(1), neutral(0))
#
# Text: Evgeni Malkin doesn\u2019t play again until the 16th. This NHL lockout sucks\u002c I can\u2019t watch games that are being played in Russia.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 31/324
# Decoded output:
#  Questionile geny Kin (’t2019t want for this the playoffs201th game He is seasonout is.
# 2016 but\u\u0029t believe the. I not played. the. IText::0):0. negative(1))
#  neutral(0))
#
# Text: Bowling tomorrow c; Don\u2019t want things to be awkard lol
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 32/324
# Decoded output:
#  Questionile  for night/o 't2019t forget to to get the;..<|end_of_text|>::0):0. negative(1))
#  neutral(0))
#
# Text: @user Happy 2nd Birthday to Prince George! Hope he has a fantastic day!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 33/324
# Decoded output:
#  Questionile j: New201nd Birthday to my Harry! He you has a great day!<|end_of_text|>Prince::0):1. negative(0))
#  neutral(0))
#
# Text: "Seriously, the SAT is just the TAKS on steroids .___."
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 34/324
# Decoded output:
#  Questionile The, I only is a a firstAKS for steroids.."
#  - ::1/n1. negative(1))
#  neutral(0))
#
# Text: Murray and Anderson have had 3 hour and 16 minute match and they are only going to the 4th set...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 35/324
# Decoded output:
#  Questionile, the, been a2 years long 30 minute long in  are still  to get 3th set.theyM::1):0. negative(1))
#  neutral(0))
#
# Text: "According to Janet Jackson's long time producer Terry Lewis, the album is due in October.  STAY CONNECTED!...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 36/324
# Decoded output:
#  Questionile The to the,'s new-awaited manager, Lewis, the singer will a out stores. The UDIO TED WITH  FollowJan:alfeat) ) negative(1)) neutral(0))
# Text: David Cameron's statement on camera on Thursday 03 September 2015: he will  take in 'more' of the refugees: was he speaking TO TV Cameras?
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 37/324
# Decoded output:
#  Questionile  M, speech on the in the 12/ 2015
#  " said not  part thea detail refugees the UK in'he referring of the cameras or orText::as) ) negative(1) neutral(0))
# Text: "Few people remember or ever knew that in his rookie season, Tom Brady, in the Pats' pecking order of quarterbacks on the team, was 4th. 4TH!"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 38/324
# Decoded output:
#  Questionile The things have the care think that the the youth year, the Brady was then  ats' firstewing order, the, the depth, was the0- in He4th! -Text::1):1), negative(1))
#  neutral(0))
#
# Text: @user have a fun trip tomorrow! Your note is on Tumblr is you didn\u2019t see it yet :) I believe in you\u002c I love you\u002c and run fast <3
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 39/324
# Decoded output:
#  Questionile j: a look day to!
#  I trip is very my.
#  a want't2019t want it.. I hope you you!2017\u believe you!002c I I with to3
# Text::1):1. negative(1))
#  neutral(0))
#  positive
# Text: @user I'm from Halifax, Nova Scotia. Not sure if we will go on March break, I'll have to see as it gets closer. Why?"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 40/324
# Decoded output:
#  Questionile j: am not the, Nova Scotia, I sure if I have be to a, but'm let to check. I's closer. I do IText::1):0. negative(1))
#  neutral(0))
#
# Text: Today's pod @user talks about the @user deal w/ the Patriots &amp; gives thoughts on NFL &amp; CFB for Thurs night
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 41/324
# Decoded output:
#  Questionile, Bible is : about the importanceuser's with/ @ @. the; the his on the freeamp; collegeFB. the..Text::0):0. negative(0))
#  neutral(0))
#
# Text: Very proud of Katy Perry in the breeders crown today ... 4th from an awkward draw .. Great drive Amanda .. First Aussie past the post ..
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 42/324
# Decoded output:
#  Questionile  good of this Perry for her newers cup.. she1th in the amazing start. but run from and  time in the post in Text::1): ) negative(0))
#  neutral(0))
#
# Text: GOP has set the bar very low with a 4th cycle promoting a grossly UN-AMERICAN idea: POTUS as elected autocrat. #Civics101
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 43/324
# Decoded output:
#  Questionile  Congressman a up stage for high for its 2% grade of a candidately unFITqualifiedERICAN agenda of thatUS should a Presidentocrat. The1oupility #
# Text::0/n. negative(1))
#  neutral(0))
#
# Text: "Holly Holm is forgiven. Dana White and the Fertittas, pictured right now...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 44/324
# Decoded output:
#  Questionile Theear,m vs a for She White is the UFCertittaas are not above,, areD::1):ly) negative(0))
#  neutral(0))
#
# Text: This is going to be a fun 5 years. The makings of the next Prime Minister... George Osborne....
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 45/324
# Decoded output:
#  Questionile  is the to be a long one2 days. I firstings of a next generation Minister of I Osborne is IText::1):. negative(1))
#  neutral(0))
#
# Text: Friday night an it\u2019s dead. Suppose I should go bed\u002c watch spartacus and nurse a glass of rum as I have no coke:( #SendMeToAsleep
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 46/324
# Decoded output:
#  Questionile,,  was2019s a. The you\u have to.2016\u theooksacus. then my hang of wine. I\u been one. I MeSomeTheylum #Text::1)0. negative(1))
#  neutral(0))
#
# Text: Free this week: August 3 Figure Four Weekly: Detailed look at why Gawker thinks the FBI covered for Hulk Hogan #wwe
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 47/324
# Decoded output:
#  Questionile, week! The 201, :
#  August look at the theker Media it Hulk is up Gaw Hogan
# 1rest #Text::1/n0. negative(1)) neutral(0))
# Text: @user  Hello Marie\u002c Are you stay in Bkk?. May God bless you:-)
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 48/324
# Decoded output:
#  Questionile j:1,,2026 I you still at therg? I I bless you and) \Text::1):1. negative(1))
#  neutral(0))
#
# Text: I'm gonna watch Sharknado 3 cause I have no tv shows to watch on a Wednesday not cause I enjoy it.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 49/324
# Decoded output:
#  Questionile  Corinthians a be younado 3: I'm nothing life and to watch. my Friday night even I'm watching but II::1):0. negative(1))
#  neutral(0))
#
# Text: Brooklyn Nets vs. the New York Knicks has been re-scheduled for November 26\u002c nationally televised on TNT. Tip-off is scheduled for 7 pm.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 50/324
# Decoded output:
#  Questionile, vs. Philadelphia New York Knicks
#  been a-scheduled for  30th2017  televised on TNT. The-off is set for 7: ET TheThe::0):. negative(1)) neutral(0))
# Text: Listening to David Bowie's #Fashion to get in the mood for @user  Can't wait for Sat night
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 51/324
# Decoded output:
#  Questionile  to the Bowie’s "1Rock # you the mood for theThem1't wait to the'sText::1)1. negative(1))
#  neutral(0))
#
# Text: @user tom Brady did not deflate balls, but was suspended for 4 games bc he may or may not have known it was being done"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 52/324
# Decoded output:
#  Questionile j:my
#  not play the for he he a for 4 games for he was have may not have def that was illegal done. picText::Positive/n0. negative(1))
#  neutral(0))
#
# Text: @user Do you think David Wright will be in the starting lineup on Monday? Thinking of road tripping it to Philly!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 53/324
# Decoded output:
#  Questionile j: you know that is is be back the lineup lineup for Sunday? I about the trippping to up see to #Text::0):0. negative(0))
#  neutral(0))
#
# Text: Omigod you guys I get to see HOLY MOTORS tomorrow.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 54/324
# Decoded output:
#  Questionile nipod, guys! love so go youLY SHORS again! II::1):1. negative(0))
#  neutral(0))
#
# Text: Fox Chicago\u002c you make me angry. Playing the Vikings vs Redskins over the NFC Championship rematch 49ers vs Giants tomorrow????
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 55/324
# Decoded output:
#  Questionile,
# 006 \u me feel. I the game,. game and weekend Championship game.2ers vs Packers..?Text::0):. negative(1))
#  neutral(0))
#
# Text: Hillary urges help for Syrian refugees: &lt;p&gt;Hillary Clinton called on the United Nations Wednesday to press cou...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 56/324
# Decoded output:
#  Questionile  Clinton Obama for the refugees
#  'quot;&gt;Hillary Clinton urged on the United States to to do fortries&Text::0):. negative(1))
#  neutral(0))
# Text: Sunday and a lovely #RaggedTalk on Skiing in Scotland by the freewheelin' Patrick D Whelan. 12:45OutoftheBlue&DrillHall #skiing #newnickname
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 57/324
# Decoded output:
#  Questionile, Monday few daySundayochys theing in the. @ lovelyerheeling' @.wyelan. # .30pm oftheBlue Theift on,Ring #Scotlandsc #Text::1) ) negative(1))
#  neutral(0))
#
# Text: REALLY??? why couldn't you have them open Pitt, MetLife, or Boston???? we're fighting
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 58/324
# Decoded output:
#  Questionile??
#  do't you have just in thes or,, or the College? could not forfor::0):. negative(1))
#  neutral(0))
#
# Text: I'm at work for 14.5 hours tomorrow lmao someone make me go to bed and stop reading articles about nicki
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 59/324
# Decoded output:
#  Questionile  Corinthians a the, the8 hours5 hours a.mao. needs a a to work early wake working this about howi minText::0:0. negative(1))
#  neutral(0))
#
# Text: @user fighters going to be a great day at Murrayfield please say happy 21st birthday to Kane that would top off his day
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 60/324
# Decoded output:
#  Questionile j:
#  to the in lot addition for thefield. come a birthday4st birthday to @ to he be it a day.
# Text::0):0. negative(0))
#  neutral(0))
#
# Text: Btw fuck Durant for going to the OKlahoma game Saturday!! You went to Texas!!! #LonghornForLife
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 61/324
# Decoded output:
#  Questionile., you, the to the LakersC City. night I are to the and YouokhNationLife
# Text::0):. negative(0))
#  neutral(0))
#
# Text: 15th seed @user defeats 20th seed Thiem and he's through to the 4th round of the @user to play Bellucci or Murray! #USOpen
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 62/324
# Decoded output:
#  Questionile 1: Sunday, @ 2th seed @ib   is now to the 3th round.
#  the Australianus tournament face @ucci in the. #ATOpen picText::0)0. negative(1)) neutral(0))
#
# Text: But it's a three day weekend and we see Ed Sheeran tomorrow (!!!!!) so things miiiight be looking up.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 63/324
# Decoded output:
#  Questionile  the is not good-way weekend, I're that anderan and night)) so we areighight get a up. IText::from):. negative(1))
#  neutral(0))
#
# Text: @user I don't understand what the fuck's wrong with you! You may hate Green Day but don't bother the Green Day Family with that!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 64/324
# Decoded output:
#  Questionile j: am't know why you problem is going with you. You're be me Lantern, you't you to people Day fans! your shit II::0):0. negative(1))
#  neutral(0))
#
# Text: Gucci gob ego ideal mystery may bare the two-sided your nose way composition against well-inclined kindled: R...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 65/324
# Decoded output:
#  Questionile illaume Manelet
#
#
#  be
#  name of face own,.. the asformedined. of. the. ReadText::1)1) negative(1))
#  neutral(0))
#
# Text: Jay-Z sat in that Interview like a God showing that he was truly ahead of his time while the other niggas flirting with Foxy Brown
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 66/324
# Decoded output:
#  Questionile ne, down the chair with he boss. off he is the a of his time. talking rest riggas were with thexy and andText::Jay)ly) negative(1))
#  neutral(0))
#
# Text: "George Lincoln Rockwell was one of the 1st to recognize that Conservatives like @user Buckley, Goldwater &amp; Reagan were #Cucks for Israel."
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 67/324
# Decoded output:
#  Questionile The Washington Rockwell, born of the most20st American use the the are myselfrealDonaldTrump_ and @water, Reagan; Reagan were theNeverulturalervatives the. #George::1/n0. negative(1))
#  neutral(0))
#
# Text: @user #SportsHalloweenCostume What about Tony Romo on sunday\u2019s game against the Giants?!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 68/324
# Decoded output:
#  Questionile j:  #ype #ume # is you Hawko? the?2029s game? the Cowboys? #Text::0):0. negative(1))
#  neutral(0))
#
# Text: When I wake up tomorrow I'll be in a different country. Whoa! I didn't run into a David Beckham at the airport. That's a bummer.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 69/324
# Decoded output:
#  Questionile  the was up in morning will be  a new place. I knows! I'm't know into any time Letter fan the airport. I's a goodummer. II::1):1. negative(1))
#  neutral(0))
#
# Text: Amazon Prime Day beats Black Friday says retailer Amazon Prime Day may have been an excuse for the retail...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 70/324
# Decoded output:
#  Questionile.com Video  Black Friday in Amazon
#
#  Day beats have beaten the even for Amazon retailer giant ReadText::1/n. negative(1)) neutral(0))
# Text: @user they go to a different place for brunch every Saturday. They started the tradition with IHOP
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 71/324
# Decoded output:
#  Questionile j: are to the place place, the. week. I have out tradition of theirOP and<|end_of_text|>::Positive/n1. negative(1))
#  neutral(0))
#  positive
# Text: CINCH YOUR SADDLE is live on Amazon!  Only 99 cents until tomorrow evening.Thank you gift!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 72/324
# Decoded output:
#  Questionile.EMAONSELFWELE! a on the Kindle Click  $99 cents!
# !
# !
# anks you for from<|end_of_text|>C fromal1): ) negative(1))
#  neutral(0))
#
# Text: Very bad idea 2 allow the dead body of Yakub to come to Mumbai-situation may become evn more tense @user @user @user
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 73/324
# Decoded output:
#  Questionile  good..1
#  the user to to theub to be out life.aysuation is be worseasive worse dangerous
#  -user @user @Text::1)1) negative(1)) neutral(0))
# Text: "Before we were all Charlie Hebdo, now we are all Parisian - tomorrow we may have to identify with others, but we must not be intimidated"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 74/324
# Decoded output:
#  Questionile The the go born born'sdo, we we are all Charlie"
#  Charlie Charlie we will be to be ourselves the who and we will never forget afraid by -Text::1):1) negative(1))
#  neutral(0))
#
# Text: "The sun shall not smite I by day, nor the moon by night" Bob Marley &amp; the Wailers NIGHT SHIFT *Live in NYC 4/30/76*
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 75/324
# Decoded output:
#  Questionile The Lord is be beatite thee, day, nor the moon by night."
#  ( Dylanley
#  The; The Wailers
#  OF
#  *  197/4/197* (Text::1)1) negative(1)) neutral(0))
#
# Text: The graves are full with people who thought they would practise islam when older not even everyone is promised tomorrow #Realtalk
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 76/324
# Decoded output:
#  Questionile  following of in of the who have they were never theirlam and they, knowing  is muslim paradise.islpostalk #Text::0 or ) negative(1)) neutral(0))
#
# Text: @user The 2nd time in the UFC to beat Rousey and a 3rd time to beat Rousey in a rematch. Then she said she's done at 135.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 77/324
# Decoded output:
#  Questionile j: following201nd of I a last I fight aonday. the 3rd time in beat theousey. the fight. @ again gets she was going with 33. IText::0):0. negative(0))
#  neutral(0))
#
# Text: @user Just saw u with Cannavaro\u002c didn\u2019t know u were here in Italy! Congratz for being the 2nd best in the world!!! #Legend
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 78/324
# Decoded output:
#  Questionile j: a this on @ibalaro and2027\u\u0029t know u were in. Italy. \ratsz on the in best1nd best player the world! \c #Text::1)0. negative(1))
#  neutral(0))
#
# Text: "\""""@nodoubt: Tune into @user tomorrow for a special @user #PushAndShove News segment during the 7AM & 9AM hours!\"""" NOOOOOOOOO"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 79/324
# Decoded output:
#  Questionile The\""""enamet@ I in thenod: for a special episodenod episodepodThePullout episode segment! the @4: hour 10AM ET!\""""\"ODOOOOOOOO<|end_of_text|>Text::0)+)), negative(1), neutral(0))
#
# Text: Digne and Falque caused Juventus real problems down their left in the 1st half. #ASRoma #Juventus
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 80/324
# Decoded output:
#  Questionile., Daise, the to trouble in the right flank the first2- half, TheJuJuoma #ASventus #Textiment:1/n0. negative(1)) neutral(0))
# Text: @user wow,ipad got just today free lol www.burna.in/fgye"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 81/324
# Decoded output:
#  Questionile j:, thatad is a. shipping..inger.com
# re
#
#  targetText::Sent/n0. negative(1), neutral(0))
#
# Text: @user you're literally incapable of intimidating me. anyways SCOTUS interprets the constitution. mar equality is the law of the land
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 82/324
# Decoded output:
#  Questionile j: are not the of reading me. I,REAMUS ists the  to Ix is not law of the land.Text::0):0. negative(0))
#  neutral(0))
#
# Text: Nooooooooo just seen the FA Cup 3rd round is the day I go skiing #peak
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 83/324
# Decoded output:
#  Questionile.oooooooo no this trailer Cup draw3rd round draw on  after have to.sdistrictText::0):0. negative(1))
#  neutral(0))
#
# Text: YOU MUST READ! Karina Smirnoff Wows in a Low-Cut Yellow Dress at the ESPY Awards (PHOTOS)
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 84/324
# Decoded output:
#  Questionile  ARE BE THIS Thisaoke’sirnoff isINS the a Bik Cutut Dress Dress at the Ys
# PHOTOS)
#  KarKar::0 or ) negative(0)
#  neutral(0))
#
# Text: We just got an email warning us that THE POPE IS COMING in two weeks. The next email said that BIEBER IS COMING tomorrow. ACK.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 85/324
# Decoded output:
#  Questionile  are got back email from us that the ENDPE IS GOING TO  weeks. I email time will that theUSHBER IS COMING in. I! IText::from):. negative(1), neutral(0))
#
# Text: "I know Battle of 5 Armies's script was written 1st, but they do so much in post these days.Are we sure none of it was inspired by Sharknado?"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 86/324
# Decoded output:
#  Questionile The am thatstar the181thies is  is written by2 year, but I didn not many more the production days, you going it of them is written by thenado <|end_of_text|> ::1):0), negative(1))
#  neutral(0))
#
# Text: One of many things that Islam has taught me is to look upon charity as something that we all must do every day that the sun rises. Powerful.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 87/324
# Decoded output:
#  Questionile  of the many that I teaches taught us is that be at the as a that is should have do. day. is sun rises. It words IText::Sent):ly) negative(1)) neutral(0))
# Text: If you're seeing the weekend instead of Paul McCartney at lolla Friday I am judging the fuck out of you.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 88/324
# Decoded output:
#  Questionile  you are looking this following's of the's, theoll,,'m sorry you world out of you. IText::1):0. negative(1))
#  neutral(0))
#
# Text: Rumour has it @user will be joining FCC on 22nd of August for fines night dress as Hulk Hogan? @user @user
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 89/324
# Decoded output:
#  Questionile ors has it that the_ be back the as the1nd of April. ase. code well Hogan.?
# user willuser @Text::0/n0. negative(1)) neutral(0))
#
# Text: Ice Cube and O'Shea are gonna appear tonight may the Lord have mercy on my soul. They're so damn fine.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 90/324
# Decoded output:
#  Questionile berg, DrDBhea Jackson the get on on  force be mercy on their soul.
#  I're gonna cool cool. IText::1):1)) negative(1))
#  neutral(0))
#
# Text: "St Pattys is no big deal for me, no fucks are given, but Cinco De Mayo on the other hand .. thats my 2nd bday ."
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 91/324
# Decoded output:
#  Questionile The.ies Day a longer deal. me. but big given given. I Ico de Mayo is the other hand,"
#  a day2 cents favoriteday present -Text::0):1. negative(1))
#  neutral(0))
#
# Text: Peru Wants 1D World Tour let's go trending trending trending till we see the sun
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 92/324
# Decoded output:
#  Questionile, to100, to Cup
# ’s go!
#
#
#  trending the get you end
# Text::1)0. negative(1)) neutral(0))
#
# Text: "Miranda hart at the NIA tomorrow night in Birmingham, A personal suggestion from my good friend Lenny Henry!"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 93/324
# Decoded output:
#  Questionile Theacles,ley the end.A,. the. KA message to the friend friend,orraine Henry. -Mir::from):1) negative(1))
#  neutral(0))
#
# Text: "Sir John dined from Justin Bieber was closed, burst into the same time--""There is too awful whisper,--""I may accelerate that"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 94/324
# Decoded output:
#  Questionile The,,' at ian's a by and into tears room time,"I is no much toing and"I am be,, (Text::1):1) negative(1))
#  neutral(0))
#  "
# Text: George Zimmerman made his first appearance in public on Friday as he and his wife Shellie have been in hiding in...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 95/324
# Decoded output:
#  Questionile  Washington, a first court in court since Thursday, he was his attorney,ie were been released hiding since Florida Text::1):. negative(1))
#  neutral(0))
#
# Text: The WAM (Write Around the Murray) Book Festival starts today at the Albury Library/Museum and goes until sunday... Go check it out!!!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 96/324
# Decoded output:
#  Questionile  followingritMW a Me Message) program Club is on and the Murraybury W.useum. runs through Sunday  The to it out!
# <|end_of_text|>Text:al1)ly) negative(2))
#  neutral(0))
#
# Text: @user Faith based discrimination, wherever it may be practised,is beyond doubt, condemnable! This is not limited to Muslims alone."
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 97/324
# Decoded output:
#  Questionile j:ful on is or it exists be,ised, a the a anable and It is the a to any,, -Text::Sent):1) negative(1), neutral(0))
# Text: Correction: Carson did not say Christians deserve more 1st Amendment protections than other religions. But what he did say was clear as mud.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 98/324
# Decoded output:
#  Questionile  of The, not say that should to than1st Amendment rights than other groups. He he he did say is that: mud. HeText::0/n. negative(0))
#  neutral(0))
#
# Text: @user I was impressed with LaRussa. Defense dominant on 1st team. Bentley ok, better near end. Deep at RB. Punting needs some work.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 99/324
# Decoded output:
#  Questionile j: am just by theikaa's He was. the3st base. I,. but than the of I threat. Iicket is work work. IText::1):1), neutral(0))
#  neutral(0))
#
# Text: RT @user Gandhi protested for years never one resorting to violence or theft. People today make me sick #londonriots
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 100/324
# Decoded output:
#  Questionile  @The:: against the against to toing to violence. even. He who are a sick.Gondon #ots
# RT::0/n. negative(1)) neutral(0))
#
# Text: Don;t forget to go the CVS tomorrow and get the Viagara. We both know you need all the encouragement you can get!!!Dreams and Visions boo:(
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 101/324
# Decoded output:
#  Questionile ’t be to check to the and and get your newagara. I have need you need it the help you can get.<|end_of_text|>s do wishesisions:!
#  IText::Text): ) negative(0))
#  neutral(0))
#
# Text: @user @user Funny how you call it ""Thursday"" and don't believe Thor was real."
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 102/324
# Decoded output:
#  Questionile j:user
# , the can me a"""" when then't even in is born. -Text::0):0. negative(1))
#  neutral(0))
#
# Text: "Taylor Swift  may ""forgive"" Kanye West all she wants, I'm not that good. God knows I'm a pro @ holding grudges. He acted as an ass. The end."
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 103/324
# Decoded output:
#  Questionile The,'s201 be beive"" her West for the wants, but'm not so forgiving at I, I've not good atk grudges. I's like if adult, I only.<|end_of_text|>Taylor::0/n1. negative(1))
#  neutral(0))
#
# Text: UCLA Study Shows Why One of the Biggest Obamacare Fears May Not Come To Pass - California Healthline
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 104/324
# Decoded output:
#  Questionile  Health: How Some in the Most Causes Problemsears Is Be Be True Pass
#  The Healthline
# Text::0/n. negative(1))
#  neutral(0))
#
# Text: I might reread the Harry Potter books for like the 7th time
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 105/324
# Decoded output:
#  Questionile  Corinthians beeread this whole Potter books again the the 100th time,and::1):1. negative(1))
#  neutral(0))
#
# Text: Sundays in the Sag is like a Friday in Idaho.....boring as fuck!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 106/324
# Decoded output:
#  Questionile, the yearrada a a family night the.itoring. hell. IS:al1)1) negative(1))
#  neutral(0))
#
# Text: @user I\u2019m going over to britain and Ireland\u2019s next top mode and jls are performing on the Monday and that\u2019s the day I was supposed
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 107/324
# Decoded output:
#  Questionile j: am2019m not to the theain for i for2019s to week model. Ik is going in the stage night Tuesday\u2019s the day I\u going toto::0)0. negative(1))
#  neutral(0))
#
# Text: "Tomorrow is National Dog Day, not to be confused with National HOT Dog Day. Though if you live in the South (lots of heat), it is the same."
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 108/324
# Decoded output:
#  Questionile The is the Coffee Day, and to be confused with National Dog Dog Day, The the you're in the South,or of you) you's National perfect day<|end_of_text|>Text::1):1. negative(1))
#  neutral(0))
#
# Text: "Just found out the craziest things about DRose's knee injury. He injured his left ACL, as did i, April 28th he injured it,29th I got surgery"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 109/324
# Decoded output:
#  Questionile The as this that newsziest thing about my.. life.. I's his knee knee and but well his. and 200th. was his again andth he did it. -Text::1):. negative(1))
#  neutral(0))
#
# Text: Serena and Venus Williams Face Off at US Open: For the 27th time, the sisters played against each other 14 yea...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 110/324
# Decoded output:
#  Questionile  Williams I Williams
#  Off in the Open
#  Serena the first1th time, Serena Williams will each each other in1 times/o
#  (Text::0):. negative(1))
#  neutral(0))
#
# Text: "Huh, Kofi Annan tomorrow. Look at you, @user Get it, get it. :-)"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 111/324
# Decoded output:
#  Questionile Theear, Iira,an,. I at that, youK_ up? @ it, I)"
# <|end_of_text|> ::0):0. negative(1))
#  neutral(0))
#
# Text: Saudi Arabia is like Narnia to me. I may HAVE to go to Mecca one day to fulfil my religious obligation but already dreading being there.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 112/324
# Decoded output:
#  Questionile  Arabia’s the aarnia, me. I love not to go back Saudicca, day, see my dream obligations, I Ireading the there. II::from):1) negative(1))
#  neutral(0))
#
# Text: "Hulk Hogan apologises for his racist comment.: Terry Bollea was at ""Good Morning America"" on Monday and he tal...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 113/324
# Decoded output:
#  Questionile Theear"'sizes for'' comments"
# "
#  Bollea, a theThe Morning America"" on Monday to said waske (Text::0):. negative(1))
#  neutral(0))
#
# Text: Good chat this morning with @user about @user terrific run in the FA Youth Cup. Lead report in Friday\u2019s Echo.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 114/324
# Decoded output:
#  Questionile  Friday with morning with aj_ theuser's @ of the @ Cup Cup. @  on the's2019s @. @Text::0):0. negative(0))
#  neutral(0))
#
# Text: "Milan fire as all fucks too, never seen the 2nd one tho."
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 115/324
# Decoded output:
#  Questionile Thewaukee,: a the go late I gonna a like2nd floor,"
#  -Date::1):0, negative(1))
#  neutral(0))
#
# Text: @user 26 i have SATS on the first of december.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 116/324
# Decoded output:
#  Questionile j:1/ have a  and the  day the and IText::S,1), negative(1), neutral(0))
# Text: "I liked a @user video John Cena lectures Nikki Bella about the laundry hampers: Total Divas, December 1,"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 117/324
# Decoded output:
#  Questionile The am the videoYouTube photo"
# ,'s on Bella on her importance roomampers in " Bellas, E 1, posted   ::1/n1. negative(1))
#  neutral(0))
#
# Text: "\""""And I never had a good time while sat by your bedside with papers and poetry about Estella.\"""""
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 118/324
# Decoded output:
#  Questionile The\" the will thought a dream time in I at the side, a in books and meh and\""""\"Text::1):1. negative(1))
#  neutral(0))
#
# Text: Bwahahaha what's going on with March Against Monsanto lately? They claim to know their "research" yet have...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 119/324
# Decoded output:
#  Questionile.anaah! a the on here this? Monsanto?? I're to be the factsfacts" is they no ReadText::0):. negative(1))
#  neutral(0))
#
# Text: It\u2019s the Saturday of a home football game aaaand I\u2019m in ISAT ... Cool.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 120/324
# Decoded output:
#  Questionile  is2019s a end before the long game game. and the\u2019m in theU. and, IText::1):. negative(1))
#  neutral(0))
#
# Text: Someone should have told Thor that sun in is just for hair and not for eyebrows
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 121/324
# Decoded output:
#  Questionile  who have told mein hesets the not a the. not for the.Text::0):0. negative(1))
#  neutral(0))
#
# Text: Name the story and season. Alien world. 5th Doctor Tegan and Turlough  The TARDIS splits up  Tractators  Name the...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 122/324
# Decoded output:
#  Questionile :  of the of The or. The1. grade.ARD. Nyurlough.6 DoctorARDIS lands up. Theappedatus  The the story Textiental1) ) negative(1)) neutral(0))
# Text: Around this time tomorrow I will be standing in the middle of Wrigley Field waiting for the Foo Fighters to come on stage!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 123/324
# Decoded output:
#  Questionile   time of, will be in in front middle of aembleley Field, for the Cubs Fighters to play on stage. II::1):1. negative(1))
#  neutral(0))
#
# Text: @user @user michael ball is incredible 10th anniversary with him and colm is sick
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 124/324
# Decoded output:
#  Questionile j:user
# @ard a.1 years of of @ and hisin. amazing Text::1):0. negative(0))
#  neutral(0))
#
# Text: "I'm already going to see Paper Towns tomorrow, so someone take me on a date to see Southpaw some other time."
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 125/324
# Decoded output:
#  Questionile The am not a to be you Plans,. but I else me to a date to see thispaw. time time. -I::1):0. negative(1))
#  neutral(0))
#
# Text: The boys are hot!! #streakin Big win tonight let\u2019s do er again tomorrow! #keepitrollin
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 126/324
# Decoded output:
#  Questionile  following are back and They1upiding
#  thanks for for's2019s see itasers! night<|end_of_text|>stitupin #Text::0):. negative(0))
#  neutral(0))
#
# Text: im going to b so pissed if ikon doesn't debut on sept 15th can YG STOP PULLING A FRANK OCEAN ON US
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 127/324
# Decoded output:
#  Questionile ago to tell a happy off i get don't win in the 1th.'t'all please FUCKLAGING MY FASTICKIECEAN AND US
# Text::0):. negative(1))
#  neutral(0))
#
# Text: Why is Jay Cutler good in the 4th qtr and not others? Good question\u002c ESPN. Could be worse\u002c though; he could be Tony Romo.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 128/324
# Decoded output:
#  Questionile  do it-Zler so at the NFL201th quartertr?
#  not in?
#  I question.2026\u\u I it a.002c ESPN. he's be worse Romo.<|end_of_text|>Text::0):0. negative(1))
#  neutral(0))
#
# Text: Kerry may you rest in peace, you will live on through your kids and grandkids who you must be so very proud of,...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 129/324
# Decoded output:
#  Questionile  O be be in peace. you were be on in your children and grandkids. will will be so proud proud of.andText::1): ) negative(1))
#  neutral(0))
#
# Text: Take note: Putting stylus back in Galaxy Note 5 may break the phone  Read more at:
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 130/324
# Decoded output:
#  Questionile  a of This theized on in the S 7 is be it phone
# 1:
#  Tech httpSamsung::0/n0. negative(1))
#  neutral(0))
#
# Text: Why wait for the videos when you can come see duels official live tomorrow? I may have vodka on my person too! Ha
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 131/324
# Decoded output:
#  Questionile  do for the next to you can watch to theet in in? night The'll be to in the breath,.<|end_of_text|>!Text::0): ) negative(1))
#  neutral(0))
#
# Text: @user digi was on the 18th but i didn't go but im going to slaybells
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 132/324
# Decoded output:
#  Questionile j:i
#  the the phone4th of I was't get to i going to theay theitch tomorrowText::1):0. negative(1))
#  neutral(0))
#
# Text: Only thing worse than sylvia finishing 2nd in wsop is dealing with selbst's wrath for making that allin call.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 133/324
# Decoded output:
#  Questionile   I than aippingan pl her2nd in theop main her with herish.  her happen the call. IS::0):0. negative(0))
#  neutral(0))
#
# Text: I'm not ready for this 5th album. I wasn't even able to handle Niall and Louis and Liam's tweets yesterday about the rumors
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 134/324
# Decoded output:
#  Questionile  Corinthians a sure to this. / grade yet I'm't ready ready to listen theINl's Harry' the and.. the album.Text::1):1. negative(1))
#  neutral(0))
#
# Text: "Ant-Man premieres tomorrow night in Doha. A savior from the atrocity that was ""Pixels."""
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 135/324
# Decoded output:
#  Questionile Theio andes in,, theaters.C, I fewizzling of the futurerocity of is theThe""<|end_of_text|>Image::1):0. negative(1))
#  neutral(0))
#
# Text: "So if the 14th amendment could not protect a women's right to vote, why would it apply to gay marriage? It wouldn't and doesn't."
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 136/324
# Decoded output:
#  Questionile The, you Son12th century is be be the black's right to vote, how should it protect to a marriage?"
#  The's't. it't. -Text::1):0. negative(1))
#  neutral(0))
#
# Text: Monsanto wants to merge with Syngenta and change name to wash away the bad reputation (3rd most disliked company!):
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 137/324
# Decoded output:
#  Questionile, to patent with Bayerngenta
#  the the to Sy their the bad smell ofM)
#  paragraph dangerous company in).
#  MonsantoM::1/n0. negative(1), neutral(0)):
#
# Text: Serena beat sister, Venus Willaims, 6-2, 1-6, 6-3,to continue her march to the calendar Grand Slam at the @user
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 138/324
# Decoded output:
#  Questionile  Williams Venus Venus sister, be in 6-4, 6-6, 6-3 in win her winning to the Australian year Slam.
#  the AustralianUSpicSer::0:0. negative(0), neutral(0))
# Text: I don't understand why they scheduled  the Sam Smith concert on the 30th omg that's so long from now :-/
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 139/324
# Decoded output:
#  Questionile  Corinthians’t know why you are this2 o concert at the same4th of the.'s so close after now.(
#  II::0):. negative(1))
#  neutral(0))
#
# ...
#  neutral(0))
#
# Text: @user Niall, hope you have a free night tomorrow 2 catch @user on TG4 &amp; tell all our friends. It's not @user Seachtar, it's better!"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 279/324
# Decoded output:
#  Questionile j:/Al O @ you are a good day to.2nd upuser N theIF. @; @ him your friends to ’s a everyuser'samusain na it's @ than<|end_of_text|><|end_of_text|>::1/n1. negative(1))
#  neutral(0))
#
# Text: RVP is getting the Hulk Hogan treatment by Man Utd. No mention of him at all. Pathetic considering he won us our 20th title.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 280/324
# Decoded output:
#  Questionile.  a a best treatment treatment. theiatd
#  The, of the being all in Ietic.
#  the's the the first1th league.<|end_of_text|>Text::0):0) negative(0))
#  neutral(0))
#
# Text: @user thank you sir Jonathan, on another note, Curtis tomorrow with Bryce Quandel and I?"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 281/324
# Decoded output:
#  Questionile j: you for for for I the note, I,, the Harperin, I will IText::0):0. negative(1))
#  neutral(0))
#
# Text: @user @user @user @user Happy Monday Folks!! Love the show aka Pulse of Jiujitsu!!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 282/324
# Decoded output:
#  Questionile j:user
# user @user @ Birthday!ks! I you new and the of theJitsu.<|end_of_text|>Text::0)0. negative(1))
#  neutral(0))
#
# Text: "12 Aug 2015 - one day, 3 countries (Philippines, Egypt, Afghanistan) 6 infidels murdered by Muslims  #tcot #ccot #TeaParty #tgdn"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 283/324
# Decoded output:
#  Questionile The: 2017   year before one1:,Chinaippines, Indonesia, and) and1,idels (,,1 ot #tcot #islaParty #tcf #<|end_of_text|>Text::1/n0. negative(1))
#  neutral(0))
#
# Text: @user 3rd party logic dictates: "That if it makes too much sense and a Nintendo platform is involved, it's simply not worth it!"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 284/324
# Decoded output:
#  Questionile j:1. party app
#  that "If's you's sense much sense, is lot Switcher involved, it's a a a it." Text::0/n1), negative(1)) neutral(0)):
# Text: Yes I am spending my Friday night listening to the Bee Gees on loop. Don't hate.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 285/324
# Decoded output:
#  Questionile, am a my time night with to the latest Gees. the. I't judge me II::1):1. negative(1))
#  neutral(0))
#
# Text: @user that sucks. I'm forced to listen to Kpop on Thursday class. I guess my cells in brain are going to die out.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 286/324
# Decoded output:
#  Questionile j: you
#  I'm not to use to thisorn music the nights. I'm I life are my are not to be.. I<|end_of_text|>::1):0. negative(1))
#  neutral(0))
#
# Text: "Now watching: FASHION KING... Hmm.. After the moon that embraces the sun,ito nmn ang pagkakaabalahan ko. Hooked n ako agad sa 1st episode"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 287/324
# Decoded output:
#  Questionile The the the The1ION WEEKDOM The, I a success, is the sun, the'saman.. fashionkakibaang ng sa Ied onmn saad sa fashion2st episode.<|end_of_text|>Text::1):1. negative(1))
#  neutral(0))
#
# Text: My son's braden 8th birthday got money in the bank briefcase due to Seth Rollins. Can you say happy birthday seth rollins to my son?
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 288/324
# Decoded output:
#  Questionile  name, nameis is2 years grade party a for the bank.case. to a'sins. I you believe " birthday?h rollins? the son.<|end_of_text|>Text::1):0. negative(1))
#  neutral(0))
#
# Text: @user omg I know Jacob :( cry with me tomorrow ?
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 289/324
# Decoded output:
#  Questionile j:g i'm I is I
#  me
# .?
# I::0):0. negative(1))
#  neutral(0))
#
# Text: "fanwars between Kpop fandoms will always happen kahit anong pigil natin. Pero at the end pag may outsider na nagbash satin, sino yung +"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 290/324
# Decoded output:
#  Questionile Thefareai" theung idolss are never be,?" naong mgailaninaman ang But k least end of nag fan na,pka, may baung nag -Text::Sent/n1. negative(1))
#  neutral(0))
#
# Text: Ice cold cider coupled with the sounds of Iron Maiden. Great Monday night...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 291/324
# Decoded output:
#  Questionile berg,, with a sweet of the Maiden, A for night musicandText::1): ) negative(1))
#  neutral(0))
#
# Text: it\u2019s ages since I had KFC\u002c well apart from the mush in a bun that passed as breakfast last SUnday\u002c that doesn\u2019t count though
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 292/324
# Decoded output:
#  Questionile  is2019s a old I last aFC.2017 but, from the facty the bucket, I for a. weeknday morning002c I was\u0029t count..I::1):1) negative(1))
#  neutral(0))
#
# Text: Tomorrow the field gets set for #Daytona500  Duels start 2pm on #SPEED All starts 10am with Nationwide practice on #ESPN2 Trucks at NOON
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 293/324
# Decoded output:
#  Questionile, world is a for theTheOfa500.202els for at2: ET NBCNBCPEEDtv the at2am on the Series. #S2
#  practice ON onText::0 or ) negative(1)) neutral(0))
# Text: With a 2nd-rd TKO, Conor McGregor backed up the talk vs Chad Mendes &amp; won the interim featherweight title at #UFC189.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 294/324
# Decoded output:
#  Questionile  the new3. editionank roundO, the McGregor is up his hype with. Mendes with now; now the fight lightweightweight title. UFCUFC200. #Video::1):0. negative(0))
#  neutral(0))
#
# Text: Poor shot selection!! And another bites in the dust. Azhar ali gone. James Pattinson gets his 2nd victim. #PakvAus #cricket
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 295/324
# Decoded output:
#  Questionile  Man,, I the one the the back. Iiz Ali was for The Andersoninson gone the first2nd w. TheAACvInd #Ausicket #Text::1) ) negative(1)) neutral(0))
# Text: @user When's your birthday again ? Mines at the very end of the month the 29th. I order Janet Jackson tickets last night
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 296/324
# Decoded output:
#  Questionile j: I the next?? I  the end end of the year. 31th. I'm a Jackson's for week.Text::0):1. negative(1))
#  neutral(0))
#
# Text: Ok I will be in the film Mt Zion which is out Feb with the man Stan Walker. The shit! Cool story bro? :)
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 297/324
# Decoded output:
#  Questionile, know admit honest the mood industry. Church is a on  the new who Lee. I film is I! bro.<|end_of_text|> IText::0) ) negative(1))
#  neutral(0))
#
# Text: And then there are those who made a case for Yakub's innocence or his possible reform if he wasn't hanged.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 298/324
# Decoded output:
#  Questionile  the the were the who are it career for theov’s innocence, at guilt innocence. he was't executedanged. TheText::1):ly) negative(1))
#  neutral(0))
#
# Text: @user @user I wouldn't be surprised with kane with sting possibly tomorrow
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 299/324
# Decoded output:
#  Questionile j:user
# 'm't be surprised if theudos's a as being.Text::0)0. negative(1)) neutral(0))
#
# Text: Pope concelebrates Mass with Armenian Patriarch: History was made on Monday when Pope Francis concelebrated mo...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 300/324
# Decoded output:
#  Questionile  Francislebrates Mass with bishops Catholicarch
#  “ of made
#  Sunday, Pope Francis celebratedlebrated Mass...
#  ViewText::0): ) negative(1))
#  neutral(0))
#
# Text: What the fuck. Paul McCartney is finally coming back to Detroit and tickets go on sale tomorrow. I don't have 8000 dollars
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 301/324
# Decoded output:
#  Questionile  is Bible is I is is a getting to to the. he are on sale this. I’m’t know any100 bucks dollars toto::1):, negative(1))
#  neutral(0))
#
# Text: Bayern lost 1-2 to Bayer Leverkusen Sunday. They remain at the top of the table and are allowed to slip up one ...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 302/324
# Decoded output:
#  Questionile  Munich 2-0 to Bor Leverkusen in, The are in the top of the Bundesliga with are now to rest up only point butText::0):1) negative(1))
#  neutral(0))
#
# Text: "Team CK vs Demolition on November 17th at the American Legion Post 80, Main St. in Binghamton NY. Get your tickets now!
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 303/324
# Decoded output:
#  Questionile Thework".onsition"  3th,   Legion in 1 in  Street. in Eastinghamton.. Come your tickets now for $Tickets::0): ) negative(1)) neutral(0))
# Text: "oh kaffir Gogdulah and kafir PKK dogs, may Allah azza wa jall take your eyes and you can not look at Muslims anymore with the eyes of hasad!"
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 304/324
# Decoded output:
#  Questionile The,aiir,-d and,,, their G,, you you curseza wa jalalla destroy you souls from ears will't see at the,, your eyes of youran and (Translation::1):1) negative(1), neutral(0))
#
# Text: @user do you know in what hotel will stay Shawn mendes on september 12th in Madrid (Spain)? Plss DM me if you know it
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 305/324
# Decoded output:
#  Questionile j: not have how which year you be in andes and his 201th? the?Spain) Is help me the you know.
# .Text::0/n0. negative(1))
#  neutral(0))
#
# Text: Kanye West @ the Hollywood bowl Sept 25th. That would be amazing tbh.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 306/324
# Decoded output:
#  Questionile  West,k  Bowl
#  201,  Photo’s be the.h. II::0):. negative(1))
#  neutral(0))
#
# Text: @user We've had 2 world wars. The 3rd will be a very different one and it will be down to Muslims &amp; their hatred of us
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 307/324
# Decoded output:
#  Questionile j: are been a2, records, We first1rd one be the nuclear different kind. will will be fought to the to Christians; Christians allies of the toText::0):1. negative(0))
#  neutral(0))
#
# Text: RT @user #Guelph Nuit Blanche tonight: 1:30am. Bookshelf Cinema parking lot - CFRU's Silent Dance Party.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 308/324
# Decoded output:
#  Questionile  @The: mailph:omin Blanche! http6.30--  launch,. lot. U   Film Party. RT::1) ) negative(1))
#  neutral(0))
#
# Text: "Lady Gaga is clearly delighted at the gift of a grey horse, delivered on Monday to her ...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 309/324
# Decoded output:
#  Questionile The of's a a with the prospect of a newhound from which to her to her home by...::from): ) negative(0)) neutral(0))
# Text: "Today, 26-years ago (August 12, 1989), Nigeria lost a rare gem to the cold hands of death. Former Super Eagles...
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 310/324
# Decoded output:
#  Questionile The, the1th-old,199 26, 1986), the's one great gem, the world hands of death. The President Eagles captain ReadText::1)ly) negative(1)) neutral(0))
# Text: Selling my Jason Aldean ticket!!! Need to get rid of it by Friday leaving for vacation !
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 311/324
# Decoded output:
#  Questionile  the house Mdean tickets to I to get it of it.. me a.!
# Jason::0):. negative(1))
#  neutral(0))
#
# Text: To whom it may concern in Luxembourg: You liked the Madoff affair you will enjoy the Apollonia Affair #affaireapollonia
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 312/324
# Decoded output:
#  Questionile  the it may concern, the, I are our articleemo scam, can like this followingfelon affairair.1airapollonia
# Text::1)1) negative(0))
#  neutral(0))
#
# Text: I can\u2019t believe the 3 important people in my life are going to Hawaii Friday without me
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 313/324
# Decoded output:
#  Questionile  Corinthians’t2019t believe it time201rd things in my life are all to be for night me.I::0):. negative(1))
#  neutral(0))
#
# Text: I still remember like 3 years ago.  Zayn told Harry that he was leaving the band on February 30th but he was joking and he said Harry cried+
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 314/324
# Decoded output:
#  Questionile  Corinthians remember the it10 years ago when I henn Malik me that he was going the band. the 1th. he didn still. he was he was.heText::1):1)) negative(1))
#  neutral(0))
#
# Text: Wow I guessed it right that Justin was gonna be on Ellen on the 8th. I was gonna get tickets but I didn't know it was gonna be in NY
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 315/324
# Decoded output:
#  Questionile, love it was! it Bieber the be the the. Monday 10th. I was right say a for I guess't. if was on be on LA.Justin::0):. negative(0))
#  neutral(0))
#
# Text: Oh and Rafa said before the injury he was having the best year he ever had was 1st in the race... :( #M6
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 316/324
# Decoded output:
#  Questionile, I., he the match that was going a best season of had had. 201st in the world andand IRoto
# Text::0):. negative(1))
#  neutral(0))
#
# Text: v sad bc a bunch of people are meeting Shawn in San Diego and I'm laying in my couch watching the day after tomorrow in Spanish
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 317/324
# Decoded output:
#  Questionile.u   of people are trying up and the Francisco. he'm going in bed bed in the news go tomorrow's the.Text::1):1. negative(1))
#  neutral(0))
#
# Text: Jiujitsu tomorrow - then ufc 155 - it's gonna be a great day I can already tell
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 318/324
# Decoded output:
#  Questionile,in
# ,  we will 1
#  then's all be a good night!
# 'm't feel.Date::0):. negative(0))
#  neutral(0))
#
# Text: They should make february 13th Desperation Day.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 319/324
# Decoded output:
#  Questionile  are be aasts 14th acribed Day. IText::1):1) negative(1))
#  neutral(0))
#
# Text: @user If you were considering a tfr to Spurs would the rioting last night put you off?
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 320/324
# Decoded output:
#  Questionile j: you are to a career-shirt, the, you followinging in night have you off?
#  II::0):0. negative(1))
#  neutral(0))
#
# Text: I love competing in the Miss America\u2019s Outstanding Teen program.. Can\u2019t wait until tomorrow! #pageantday
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 321/324
# Decoded output:
#  Questionile  Corinthians you in the  America Page2019s Outstanding Teen page. I\u2019t wait to next to IMissant # #Text::1):. negative(1))
#  neutral(0))
#
# Text: Hulk Hogan may be a real American but he's no longer a great American.
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 322/324
# Decoded output:
#  Questionile  #, have the former-life hero he is not American a real American. HeH::0):0. negative(1))
#  neutral(0))
#
# Text: Don't forget to sign up for the DC Walk to End HIV taking place next Saturday from 8:00 - 11:00 AM. Register here:
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 323/324
# Decoded output:
#  Questionile ’t be to check up for the  Comics for End Alzheimer on place on month, 10:30am 11:00 am at The here. httpsText:al1) ) negative(2), neutral(0))
#
# Text: Federer beats Murray 6-4, 7-6(6) to reach #CincyTennis final. He'll be going for his 7th title vs Novak Djokovic, who is going for his first
# Sentiment (positive(2), negative(0), neutral(1)):
# Count: 324/324
# Decoded output:
#  Questionile ico, Nad to6-4, 6-6 (5), in win 1incyFinalennis final
#  Feder will face playing for his 7th Cincinnati of.ak Djokovic.
#  who beat  for his.
# Text::0):0. negative(0))
#  neutral(0))
#
# Negatives: 0
# Neutrals: 7
# Positives: 317

# %%
#tweet = dataset['validation'][0]['text'] # label is zero
tweet = "I hate waiting in line"
'''
  Cleaning the tweet before processing doesn't appear to help
'''
import re
def clean_output(tweet):
    # Remove unwanted characters and sequences
    cleaned_text = re.sub(r'[^A-Za-z0-9\s,.?!]', '', tweet)  # Keep only letters, numbers, and some punctuation
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()  # Remove extra whitespace
    return cleaned_text
clean_tweet = clean_output(tweet)
print(f"Cleaned Tweet: {clean_tweet}\n")

prompt= f"Text: {clean_tweet} \nSentiment (positive(2), negative(0), neutral(1)):"
print(f"Prompt:\n {prompt}\n")

best_option, log_probs = calculate_option_log_prob(prompt, sentiment_ids)
print(f"Predicted sentiment: {best_option}\n")
print("Log probabilities:", log_probs)

# %%
'''
  Method #1: parse output text for keywords and keep list of labels
'''

from transformers import AutoTokenizer, AutoModelForCausalLM
from sklearn.metrics import precision_score, recall_score, f1_score

# tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3.5-mini-instruct")
# model = AutoModelForCausalLM.from_pretrained("microsoft/Phi-3.5-mini-instruct")

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-3B")
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-3B")


# Sample sentences and actual labels
# sentences = [
#     "I love this product!",            # Expected label: 2 (positive)
#     "This is okay.",                   # Expected label: 1 (neutral)
#     "I hate waiting in line.",         # Expected label: 0 (negative)
# ]
#actual_labels = [2, 1, 0]  # Corresponding actual labels

sentences = dataset['validation']['text'][:10]
actual_labels = dataset['validation']['label'][:10]


# Prepare a function to classify sentences
def classify_sentences(sentences):
    predictions = []
    for sentence in sentences:
        #prompt = f"Classify this sentence: '{sentence}' as 0 (negative), 1 (neutral), or 2 (positive)."
        prompt = f"Classify this sentence as negative (0), neutral (1), or positive (2). Only pick one number and only respond with the number. If it's negative output 0, if it's neutral ouput 1, if it's negative out 2. Here's the sentence: {sentence}"

        inputs = tokenizer(prompt, return_tensors='pt')
        outputs = model.generate(**inputs, max_new_tokens=200)
        classification = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(classification)

        # Simple mapping to numerical labels
        if "negative" in classification:
            predictions.append(0)
        elif "neutral" in classification:
            predictions.append(1)
        elif "positive" in classification:
            predictions.append(2)
        else:
            predictions.append(-1)  # If the classification is unclear

    return predictions

# Classify sentences
predicted_labels = classify_sentences(sentences)

# Calculate precision, recall, and F1 score
precision = precision_score(actual_labels, predicted_labels, average='weighted')
recall = recall_score(actual_labels, predicted_labels, average='weighted')
f1 = f1_score(actual_labels, predicted_labels, average='weighted')

# Print results
print(f"Predicted labels: {predicted_labels}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   4%|4         | 199M/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
'''
  Verifying that precision, recall, and f1 are calculated accurately when using
  lists of labels in method #1
'''

predicted_labels = [0, 0, 1, 1, 2, 2]
actual_labels = [1, 1, 2, 2, 0, 0]

# Calculate precision, recall, and F1 score
precision = precision_score(actual_labels, predicted_labels, average='weighted')
recall = recall_score(actual_labels, predicted_labels, average='weighted')
f1 = f1_score(actual_labels, predicted_labels, average='weighted')

# Print results
print(f"Predicted labels: {predicted_labels}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Predicted labels: [0, 0, 1, 1, 2, 2]
# Precision: 0.00
# Recall: 0.00
# F1 Score: 0.00
